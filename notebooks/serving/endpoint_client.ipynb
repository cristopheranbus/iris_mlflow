# %% [markdown]
# # Cliente REST para Databricks Model Serving
#
# Este notebook usa el cliente compartido de `iris_mlflow_utils.serving`; no duplica autenticación ni validación HTTP. Configura `DATABRICKS_HOST`, `DATABRICKS_TOKEN` y `DATABRICKS_ENDPOINT_NAME` mediante un mecanismo seguro.

# %%
# Las importaciones se incluyen en el ejemplo ejecutable de la siguiente celda.

# %% [markdown]
# ## Ejemplo de uso
#
# Descomenta la celda cuando las variables seguras y el endpoint estén disponibles.

# %%
# import pandas as pd
# from iris_mlflow_utils import predict_dataframe
#
# features = pd.DataFrame(
#     [[5.1, 3.5, 1.4, 0.2]],
#     columns=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"],
# )
# display(predict_dataframe(features))
